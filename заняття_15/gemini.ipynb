# %%
import requests

# %%
GEMINI_API_KEY = ""
GEMINI_MODEL = "gemini-2.5-flash" # "gemini-2.5-flash-lite"
url = f"https://generativelanguage.googleapis.com/v1beta/models/{GEMINI_MODEL}:generateContent?key={GEMINI_API_KEY}"
payload = {
    "contents": [
        {"parts": [{"text": "Напиши один короткий рядок про переваги вивчення програмування."}]}
    ]
}
response = requests.post(url, json=payload, timeout=60)
response.raise_for_status()
data = response.json()
print(data)
# Out:
# {'candidates': [{'content': {'parts': [{'text': '**Код дає силу творити майбутнє.**'}], 'role': 'model'}, 'finishReason': 'STOP', 'index': 0}], 'usageMetadata': {'promptTokenCount': 18, 'candidatesTokenCount': 13, 'totalTokenCount': 1639, 'promptTokensDetails': [{'modality': 'TEXT', 'tokenCount': 18}], 'thoughtsTokenCount': 1608, 'serviceTier': 'standard'}, 'modelVersion': 'gemini-2.5-flash', 'responseId': 'c_RHatLXFueMkdUPrdaEsQI'}
