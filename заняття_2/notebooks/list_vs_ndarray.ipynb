# %%
import time
import numpy as np

# Великий масив
size = 1000000
python_list = list(range(size))
numpy_array = np.arange(size)

print("--- Performance Comparison ---")
print(f"Розмір масиву: {size:,} елементів\n")

# Python list (using list comprehension)
start = time.time()
result_python = [x + 1 for x in python_list]
time_python = time.time() - start
print(f"Python list addition: {time_python:.6f} секунд")

# NumPy array (vectorized)
start = time.time()
result_numpy = numpy_array + 1
time_numpy = time.time() - start
print(f"NumPy array addition: {time_numpy:.6f} секунд")
print(f"\nNumPy в {time_python/time_numpy:.1f}x швидший!")
# Out:
# --- Performance Comparison ---
# Розмір масиву: 1,000,000 елементів
#
# Python list addition: 0.032807 секунд
# NumPy array addition: 0.001358 секунд
#
# NumPy в 24.2x швидший!
